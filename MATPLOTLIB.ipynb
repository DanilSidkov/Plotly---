# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('1.csv')

# %%
x = [i/100 for i in range(0, 200)]
y = [round(i**0.5,2) for i in x]
y1 = [round(i**2,2) for i in x]
plt.figure(figsize=(15,7))

plt.subplot(1,3,1)
plt.plot(x, y, label = "X**0.5", color = 'brown', linestyle = '-.')
plt.title(label = "Dependence consuming drinks", loc = 'left', fontsize = 'x-large', fontstyle = 'oblique', fontweight = "demibold", color = 'green')
plt.xlabel(xlabel = "X", fontsize = 'medium', fontstyle = 'normal', fontweight = 'heavy', color = 'red')
plt.ylabel(ylabel = "Y", fontsize = 'large', fontstyle = 'italic', fontweight = 'regular', color = 'blue')
plt.text(1,1, '*', color = 'black', fontsize= 'xx-large')
plt.grid(True)
plt.legend()

plt.subplot(1,3,2)
plt.plot(x, y1, label = "X**2", color = 'blue', linestyle = ':')
plt.title(label = "Dependence consuming drinks", loc = 'left', fontsize = 'x-large', fontstyle = 'oblique', fontweight = "demibold", color = 'green')
plt.xlabel(xlabel = "X", fontsize = 'medium', fontstyle = 'normal', fontweight = 'heavy', color = 'red')
plt.ylabel(ylabel = "Y", fontsize = 'large', fontstyle = 'italic', fontweight = 'regular', color = 'blue')
plt.text(1,1, '*', color = 'black', fontsize= 'xx-large')
plt.grid(True)
plt.legend()

plt.subplot(1,3,3)
plt.plot(x, y, label = "X**0.5", color = 'brown', linestyle = '-.')
plt.plot(x, y1, label = "X**2", color = 'blue', linestyle = ':')
plt.title(label = "Dependence consuming drinks", loc = 'left', fontsize = 'x-large', fontstyle = 'oblique', fontweight = "demibold", color = 'green')
plt.xlabel(xlabel = "X", fontsize = 'medium', fontstyle = 'normal', fontweight = 'heavy', color = 'red')
plt.ylabel(ylabel = "Y", fontsize = 'large', fontstyle = 'italic', fontweight = 'regular', color = 'blue')
plt.text(1,1, '*', color = 'black', fontsize= 'xx-large')
plt.grid(True)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
plt.plot(df.index, df.a0,label = 'A0', color = 'red', linestyle = ':')
plt.title(label = "Plot A0", loc='left', fontsize='x-large', fontstyle='normal', fontweight='regular', color = 'black')
plt.xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.legend(loc=0, frameon = True, framealpha = 0.2, facecolor = 'red', edgecolor = 'blue', title = 'LEGEND', title_fontsize = '10')
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(df.index, df.a1, label = 'A1', color = "blue", linestyle = "-.")
plt.title(label = "Plot A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='bold', color = 'black')
plt.xlabel(xlabel = 'X', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.ylabel(ylabel = 'Y', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.legend(loc=0, frameon = True, framealpha = 0.7, facecolor = 'yellow', edgecolor = 'red', title = 'LEGEND', title_fontsize = '10')
plt.grid(True)

plt.subplot(2,2,3)
plt.plot(df.index, df.a0,'x', label = 'A0' ,color = 'red', linestyle = ':')
plt.plot(df.index, df.a1,'o', label = 'A1', color = "blue", linestyle = "-.")
plt.title(label = "Plot A0&A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.legend(['A0_GRAPH','A1_GRAPH'], loc=0, frameon=True, framealpha = 0.2, facecolor = 'blue', edgecolor = 'black', title = 'LEGEND')
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(df.index, df.a0*df.a1, label = 'A0' ,color = 'red', linestyle = ':')
plt.title(label = "Plot A0-A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='semibold', color = 'black')
plt.xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
plt.legend(['A0-A1'], loc=0, frameon=True, framealpha = 0.5, facecolor = 'yellow', edgecolor = 'black', title = 'LEGEND')
plt.grid(True)

# %%
fg = plt.figure(figsize=(16, 16), constrained_layout=True)
gs = fg.add_gridspec(8, 8)

fig_ax_1 = fg.add_subplot(gs[:3, :3])
fig_ax_1.set_title(label = "Plot A0", loc='left', fontsize='x-large', fontstyle='normal', fontweight='bold', color = 'black', pad = 1)
fig_ax_1.plot(df.index, df.a0,label = 'A0', color = 'red', linestyle = ':')
fig_ax_1.set_xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_1.set_ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_1.legend(loc='right', frameon = True, framealpha = 0.2, facecolor = 'red', edgecolor = 'blue', title = 'LEGEND', title_fontsize = '10')
fig_ax_1.grid(True)
fig_ax_1.set_xlim(200,800)
fig_ax_1.set_ylim(-2,2)

fig_ax_2 = fg.add_subplot(gs[:3, 3:])
fig_ax_2.set_title(label = "Plot A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='bold', color = 'black', pad = 1)
fig_ax_2.plot(df.index, df.a1, label = 'A1', color = "blue", linestyle = "-.")
fig_ax_2.annotate('LOOK!', xy=(410, 5.5), xytext=(0, 4), xycoords = 'data', textcoords = 'data', 
                  bbox=dict(boxstyle='round,pad=0.2',ec='k',fc='w',ls='-',lw=1),
                  arrowprops=dict(facecolor='black', shrink=0.05))
fig_ax_2.set_xlabel(xlabel = 'X', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_2.set_ylabel(ylabel = 'Y', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_2.legend(loc=0, frameon = True, framealpha = 0.7, facecolor = 'yellow', edgecolor = 'red', title = 'LEGEND', title_fontsize = '10')
fig_ax_2.grid(True)

fig_ax_3 = fg.add_subplot(gs[3:, :3])
fig_ax_3.set_title(label = "Plot A0-A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='semibold', color = 'black', pad = 1)
fig_ax_3.plot(df.index, df.a0*df.a1, label = 'A0' ,color = 'red', linestyle = ':')
fig_ax_3.set_xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_3.set_ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_3.legend(['A0-A1'], loc=0, frameon=True, framealpha = 0.5, facecolor = 'yellow', edgecolor = 'black', title = 'LEGEND')
fig_ax_3.grid(True)

fig_ax_4 = fg.add_subplot(gs[3:, 3:])
fig_ax_4.set_title(label = "Plot A0&A1", loc='left', fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black', pad = 1)
fig_ax_4.plot(df.index, df.a0, label = 'A0' ,color = 'red', linestyle = '-', linewidth = 4, markevery = 10, ms=10, marker='d',mfc='black')
fig_ax_4.plot(df.index, df.a1,mfc='yellow',mew='1',mec='black', ms = 20, marker='o',label = 'A1', fillstyle = 'left', alpha = 0.5)
fig_ax_4.fill_between(df.index, df.a0, df.a1, color = 'green', alpha = 0.2)
fig_ax_4.set_xlabel(xlabel = 'X',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_4.set_ylabel(ylabel = 'Y',fontsize='x-large', fontstyle='normal', fontweight='demibold', color = 'black')
fig_ax_4.legend(['A0_GRAPH','A1_GRAPH'], loc=0, frameon=True, framealpha = 0.2, facecolor = 'blue', edgecolor = 'black', title = 'LEGEND')
fig_ax_4.grid(True)

# %%
np.random.seed(42)
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
val = np.random.randint(10, size=(10,10))
plt.pcolor(val)
plt.colorbar(label = 'Value', shrink = 0.95)

plt.subplot(1,2,2)
val = np.random.randint(11, size=(10,10))
plt.pcolor(val, cmap = plt.get_cmap('viridis', 11))
cbar = plt.colorbar(orientation='horizontal',shrink=1.2, extend='min', extendfrac=0.2,
                    extendrect=False, drawedges=True, label = 'Value', ticks = [0,5,10])
cbar.ax.set_xticklabels(['Low', 'Medium', 'High'])
# Out:
# [Text(0, 0, 'Low'), Text(5, 0, 'Medium'), Text(10, 0, 'High')]

# %%
fg = plt.figure(figsize = (16,16), constrained_layout = True)
gs = fg.add_gridspec(10,6)

fig_ax_1 = fg.add_subplot(gs[:3, :3])
fig_ax_1.set_title(label='Plot #1', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_1.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_1.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_1.plot(df.index, df.a1, linestyle="-", linewidth=1, color = 'blue', markevery = 10, ms = 5, mec = 'black', mfc = 'red', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
fig_ax_1.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
fig_ax_1.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
fig_ax_1.legend(['A1','A0'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_1.grid(True)
fig_ax_1.set_xlim(200,900)
fig_ax_1.set_ylim(0,6)

fig_ax_2 = fg.add_subplot(gs[:3, 3:])
fig_ax_2.set_title(label='Plot #2', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_2.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_2.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_2.plot(df.index, df.a0*df.a1, linestyle="-", linewidth=1, color = 'blue', markevery = 10, ms = 5, mec = 'black', mfc = 'red', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
#fig_ax_2.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
#fig_ax_2.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
fig_ax_2.legend(['A1*A0'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_2.grid(True)
#fig_ax_2.set_xlim(200,900)
#fig_ax_2.set_ylim(0,6)

fig_ax_3 = fg.add_subplot(gs[3:5, 0:])
fig_ax_3.set_title(label='Plot #3', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_3.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_3.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_3.plot(df.index, df.a0*df.a0, linestyle="-", linewidth=1, color = 'blue', markevery = 90, ms = 5, mec = 'black', mfc = 'blue', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
#fig_ax_3.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
#fig_ax_3.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
fig_ax_3.legend(['A0^2'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_3.grid(True)
#fig_ax_3.set_xlim(200,900)
#fig_ax_3.set_ylim(0,6)

fig_ax_4 = fg.add_subplot(gs[5:7, 0:])
fig_ax_4.set_title(label='Plot #4', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_4.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_4.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_4.plot(df.index, df.a1*df.a1, linestyle=":", linewidth=1, color = 'black', markevery = 40, ms = 5, mec = 'black', mfc = 'blue', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
#fig_ax_4.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
#fig_ax_4.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
fig_ax_4.legend(['A1^2'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_4.grid(True)
#fig_ax_4.set_xlim(200,900)
#fig_ax_4.set_ylim(0,6)

fig_ax_5 = fg.add_subplot(gs[7:, :3])
fig_ax_5.set_title(label='Plot #4', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_5.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_5.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_5.plot(df.index, df.a0*df.a0*df.a1, linestyle="-.", linewidth=1, color = 'black', markevery = 50, ms = 5, mec = 'black', mfc = 'blue', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
#fig_ax_5.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
#fig_ax_5.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
fig_ax_5.legend(['A0^2*A1'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_5.grid(True)
#fig_ax_5.set_xlim(200,900)
#fig_ax_5.set_ylim(0,6)

fig_ax_6 = fg.add_subplot(gs[7:, 3:])
fig_ax_6.set_title(label='Plot #4', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
fig_ax_6.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_6.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
fig_ax_6.plot(df.index, df.a1*df.a1*df.a0, linestyle="-", linewidth=1, color = 'black', markevery = 70, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
fig_ax_6.plot(df.index, df.a0, linestyle="--", linewidth=1, color = 'red', markevery = 100, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
fig_ax_6.fill_between(df.index,-25,25, color='red', alpha=0.2)
fig_ax_6.legend(['A1^2*A0'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
fig_ax_6.grid(True)

plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: constrained_layout not applied.  At least one axes collapsed to zero width or height.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
bc = mcolors.BASE_COLORS
x = np.arange(1,10)
y = x
val = np.random.randint(11,size=(10,10))
x1 = np.arange(0, 10.5, 0.5)
y1 = np.cos(x1)
np.random.seed(123)
groups = [f'P{i}' for i in range(7)]
counts = np.random.randint(0, len(bc), len(groups))
width = counts*0.1
colors = [['r', 'b', 'g'][int(np.random.randint(0, 3, 1))] for _ in
counts]

fx = plt.figure(figsize=(15,7), constrained_layout = True)
gx = fx.add_gridspec(10,10)

plot1 = fx.add_subplot(gx[:4,:4])
plot1.step(x, y, where='post', marker='o', mfc='green', mec='black',ms=5, mew=1, linewidth=3, color='red')
plot1.set_title('StepPlot', loc='center', fontstyle='oblique', fontsize='xx-large', fontweight='semibold', color='black')
plot1.set_xlabel('X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot1.set_ylabel('Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot1.fill_between(x,4,7, color='green', alpha=0.2)
plot1.legend(['Steps'], facecolor='orange', edgecolor='black', frameon=True, framealpha=0.2, loc=0, title='Legend')
plot1.grid(True)

plot2 = fx.add_subplot(gx[:4,4:7])
plot2.set_title('ColorMap', loc='center', fontstyle='oblique', fontsize='xx-large', fontweight='semibold', color='black')
plot2.set_xlabel('Quality', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot2.set_ylabel('Price', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
cbar = plt.colorbar(plot2.pcolormesh(val, cmap=plt.get_cmap('plasma', 3)),orientation='vertical', shrink=1.2, drawedges=True, label='Value', extendrect=False, extend='max', extendfrac=0.1)

plot3 = fx.add_subplot(gx[4:7,:4])
plot3.set_title('StackPlot', loc='center', fontstyle='oblique', fontsize='xx-large', fontweight='semibold', color='black')
plot3.set_xlabel('X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot3.set_ylabel('Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot3.stackplot(df.index, df.a0, df.a1, labels=['a0','a1'])
plot3.legend(facecolor='orange', edgecolor='black', frameon=True, framealpha=0.2, loc='upper left', title='Legend')
plot3.grid(True)

plot4 = fx.add_subplot(gx[4:7, 4:7])
plot4.set_title(label='ClassicPlot', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
plot4.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot4.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot4.plot(df.index, df.a1*df.a1, linestyle=":", linewidth=1, color = 'black', markevery = 40, ms = 5, mec = 'black', mfc = 'blue', mew='1', marker='o', label ='A1', fillstyle='full',alpha=1)
#fig_ax_4.plot(df.index, df.a0, linestyle="-", linewidth=1, color = 'red', markevery = 10, ms = 5, mec = 'black', mfc = 'yellow', mew='1', marker='s', label ='A0' ,fillstyle='full',alpha=1)
#fig_ax_4.fill_between(df.index,df.a0,df.a1, color='green', alpha=0.2)
plot4.legend(['A1^2'], loc=0, title='LEGEND', frameon=True, facecolor='green', edgecolor='black', framealpha=0.2)
plot4.grid(True)
#fig_ax_4.set_xlim(200,900)
#fig_ax_4.set_ylim(0,6)

plot5 = fx.add_subplot(gx[:, 7:])
plot5.set_title(label='StemPlot', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
plot5.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot5.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot5.stem(x, y, linefmt='r--', markerfmt='^', bottom = 3)

plot6 = fx.add_subplot(gx[7:,:4])
plot6.set_title(label='ScatterPlot', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
plot6.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot6.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot6.scatter(x1,y1, s=50, cmap='viridis', edgecolors='black', linewidth=3, marker='o', alpha = 0.3)

plot7 = fx.add_subplot(gx[7:,4:7])
plot7.set_title(label='BarPlot', loc='left', fontsize='x-large', fontstyle='oblique', fontweight='demibold', color='black', pad=1)
plot7.set_xlabel(xlabel='X', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot7.set_ylabel(ylabel='Y', fontsize='medium', fontstyle='normal', fontweight='semibold', color='black')
plot7.bar(groups, counts, width=width, alpha=0.6, bottom=2, color=colors, edgecolor='k', linewidth=2)

plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: constrained_layout not applied.  At least one axes collapsed to zero width or height.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data = np.random.randn(25, 25)
fig, axs = plt.subplots(1, 3, figsize=(10,3), constrained_layout=True)
p1 = axs[0].imshow(data, cmap='winter', aspect='equal', vmin=-1, vmax=1,
origin='lower')
fig.colorbar(p1, ax=axs[0])
p2 = axs[1].imshow(data, cmap='plasma', aspect='equal',
interpolation='gaussian', origin='lower', extent=(0, 30, 0, 30))
fig.colorbar(p2, ax=axs[1])
data = np.random.rand(5, 7)
axs[2].pcolormesh(data, cmap='plasma', edgecolors='k', shading='flat')
plt.show()

# %%
vals = [24, 17, 53, 21, 35]
labels = ['Ford', 'Toyota', 'BMV', 'AUDI', 'Jaguar']
offset=0.4
data = np.array([[5, 10, 7], [8, 15, 5], [11, 9, 7]])
cmap = plt.get_cmap('tab20b')
b_colors = cmap(np.array([0, 8, 12]))
sm_colors = cmap(np.array([1, 2, 3, 9, 10, 11, 13, 14, 15]))
vals = [24, 17, 53, 21, 35]
labels = ['Ford', 'Toyota', 'BMW', 'AUDI', 'Jaguar']
explode = (0.1, 0, 0.15, 0, 0)

fx = plt.figure(figsize=(15,15), constrained_layout = True)
gx = fx.add_gridspec(7,7)

p1 = fx.add_subplot(gx[:3,:3])
p1.pie(vals, labels=labels, wedgeprops=dict(width=0.5))

p2 = fx.add_subplot(gx[:3,3:5])
p2.pie(data.sum(axis=1), radius=1, colors=b_colors, wedgeprops=dict(width=offset, edgecolor='w'))
p2.pie(data.flatten(), radius=1-offset, colors=sm_colors, wedgeprops=dict(width=offset, edgecolor='w'))

p3 = fx.add_subplot(gx[3:5,:3])
p3.pie(vals, labels=labels, autopct='%1.1f%%', shadow=True, explode=explode, wedgeprops={'lw':1, 'ls':'--','edgecolor':'k'}, rotatelabels=True)
p3.axis('equal')

p4 = fx.add_subplot(gx[3:5,3:5])
p4.pie(vals, labels=labels)
p4.axis('equal')

plt.show()

# %%
np.random.seed(123)
rnd = np.random.randint
cat_par = [f'P{i}' for i in range(5)]
g1 = [10, 21, 34, 12, 27]
error = np.array([[rnd(2,7),rnd(2,7)] for _ in range(len(cat_par))]).T

fig, axs = plt.subplots(1, 3, figsize=(15, 10))

# Первый график
axs[0].bar(cat_par, g1, yerr=5, ecolor='r', alpha=0.5, edgecolor='b',linewidth=2)
axs[0].set_title('Первый график')

# Второй график
axs[1].bar(cat_par, g1, yerr=error, ecolor='r', alpha=0.5, edgecolor='b',linewidth=2)
axs[1].set_title('Второй график')

# Третий график
g2 = [17, 15, 25, 21, 26]
width = 0.3
x = np.arange(len(cat_par))
rects1 = axs[2].bar(x - width/2, g1, width, label='g1')
rects2 = axs[2].bar(x + width/2, g2, width, label='g2')
axs[2].set_title('Третий график')
axs[2].set_xticks(x)
axs[2].set_xticklabels(cat_par)
axs[2].legend()

plt.show()

# %%
# Создаем фигуру с размером
fig = plt.figure(figsize=(15, 15))

# Первый график
ax1 = fig.add_subplot(2, 2, 1, projection='3d')
x = np.linspace(-np.pi, np.pi, 50)
y = x**2
z = np.cos(x)*np.exp(x)
ax1.plot(x, y, z, label='parametric curve', markevery=10, marker='o', linestyle=':', mfc='green')
ax1.legend()

# Второй график
ax2 = fig.add_subplot(2, 2, 2, projection='3d')
np.random.seed(123)
x = np.random.randint(-5, 5, 40)
y = np.random.randint(0, 10, 40)
z = np.random.randint(-5, 5, 40)
s = np.random.randint(10, 100, 40)
ax2.scatter(x, y, z, s=s)

# Третий график
ax3 = fig.add_subplot(2, 2, 3, projection='3d')
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax3.plot_wireframe(x, y, z)

# Четвертый график
ax4 = fig.add_subplot(2, 2, 4, projection='3d')
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax4.plot_surface(x, y, z, cmap='inferno')

plt.show()

# %%
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...
