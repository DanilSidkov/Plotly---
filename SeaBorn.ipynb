# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import itertools

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.ecdfplot(data)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %%
sns.relplot(x='year', y='passengers', kind='line', data=flights)

# %%
plt.figure(figsize=(10,7))

col = iris.columns
col = [i for i in col if i!='species']

for i in col:
    sns.catplot(x='species', y=i, kind='swarm', data=iris)
    plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,7))

col = iris.columns
col = [i for i in col if i!='species']
combinations = list(itertools.combinations(col,3))

for i in combinations:
    print(i)
    sns.relplot(x=i[0],y=i[1],size=i[2],data=iris)
    plt.show()
# Out:
# ('sepal_length', 'sepal_width', 'petal_length')
# ('sepal_length', 'sepal_width', 'petal_width')
# ('sepal_length', 'petal_length', 'petal_width')
# ('sepal_width', 'petal_length', 'petal_width')

# %%
sns.set_style('whitegrid')
sns.set_context('paper')
sns.relplot(x='species',y='sepal_length',kind='line',data=iris)

# %%
sns.boxplot(x='gender', y='age', data=db)
plt.show()
sns.violinplot(x='gender', y='age', hue='diabetes',data=db)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
plt.figure(figsize=(15,7))
sns.distplot(x=db['bmi'], hist=True, kde=True, rug = True, color='g', vertical = False,axlabel="chi-square values")
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.barplot(x='gender',y='bmi',data=db)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='bmi'>

# %%
db
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
sns.kdeplot(iris['petal_length'], iris['sepal_width'], shade=True, cmap='plasma',cbar=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>

# %%
jp = sns.JointGrid(x='sepal_length', y='sepal_width', data=iris)
jp.plot_joint(sns.regplot, color="g")
jp.plot_marginals(sns.kdeplot, shade=True, color='r')

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind="resid",ratio=5,space=0)

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind="hex")

# %%
sns.jointplot(x='sepal_length', y='petal_length', data=iris, kind="kde")

# %%
sns.jointplot(x='sepal_length', y='petal_length', data=iris, kind="reg")

# %%
mpg = sns.load_dataset("mpg")
mpg_mod = mpg[["mpg", "horsepower", "displacement", "origin"]]
sns.pairplot(mpg_mod, hue="origin", vars=["mpg", "horsepower"])

# %%
h_order = ["virginica", "setosa", "versicolor"]
sns.lmplot(x="sepal_width", y="petal_width", hue="species", hue_order=h_order, data=iris)

# %%
sns.lmplot(x="sepal_length", y="sepal_width", hue="species", palette="Dark2", col="species", height=3, aspect=1.5, data=iris)

# %%
sns.regplot(x="mpg", y="displacement", order=3, data=mpg)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
ps = pd.read_csv('ww.csv', sep=';')

# %%
ps.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
sns.set_style('whitegrid')
sns.relplot(y='residual sugar',x='quality', kind='line',data=ps)

# %%
sns.set_style('whitegrid')
sns.relplot(x='total sulfur dioxide', y='volatile acidity', size='alcohol', hue='quality' ,data=ps)

# %%
sns.kdeplot(x=ps['total sulfur dioxide'], y=ps['pH'], shade=True, cmap='plasma',cbar=True)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='pH'>

# %%
jp = sns.JointGrid(x='total sulfur dioxide', y='pH', data=ps)
jp.plot_joint(sns.regplot, color="y")
jp.plot_marginals(sns.kdeplot, shade=True, color='r')

# %%
sns.jointplot(x='total sulfur dioxide', y='pH', data=ps, kind="reg")

# %%
sns.jointplot(x='total sulfur dioxide', y='pH', data=ps, kind="kde")

# %%
sns.jointplot(x='total sulfur dioxide', y='pH', data=ps, kind="hex")

# %%
sns.regplot(x='total sulfur dioxide', y='pH', order=3, data=ps)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='pH'>
